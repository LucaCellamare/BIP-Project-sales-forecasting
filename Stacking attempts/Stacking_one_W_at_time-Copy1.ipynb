# %%
import pandas as pd
import numpy as np
from datetime import date, datetime, time, timedelta
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.metrics import mean_squared_error

from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder


# %config InlineBackend.figure_format = 'retina' 
# %matplotlib inline

#models
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.ensemble import ExtraTreesRegressor

 
mpl.rcParams['lines.linewidth'] = 2

figsize=(12,9)

np.random.seed(238746)


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# TRAIN-TEST SPLIT DATE

# %%
SplitTestDate = "2019-06-23"

# %% [markdown]
# ### MODEL SELECTION AND FEATURE SELECTION

# %%
models = {
    "xgb" : xgb.XGBRegressor(n_estimators=500, learning_rate=0.1),
    "extra": ExtraTreesRegressor(n_estimators=500),
    #"forest" : RandomForestRegressor(n_estimators=100)
}

features_for_model = {

    "xgb" : ['scaled_month',
            "group_A","group_B","BRAND2","BRAND4",
           'scaled_dayofyear','scaled_dayofmonth','scaled_weekofyear',"scaled_sales1","scaled_sales2","scaled_sales3",
            'scaled_promo','scaled_diff1','scaled_diff2','percentage_diff1','scaled_price',"scaled_rolling2"],
    "extra": ['scaled_month',
            "group_A","group_B","BRAND2","BRAND4",
           'scaled_dayofyear','scaled_dayofmonth','scaled_weekofyear',"scaled_sales1","scaled_sales2","scaled_sales3",
            'scaled_promo','scaled_diff1','scaled_diff2','percentage_diff1','scaled_price',"scaled_rolling2"],
    "forest": ['scaled_month',
            "group_A","group_B","BRAND2","BRAND4",
           'scaled_dayofyear','scaled_dayofmonth','scaled_weekofyear',"scaled_sales1","scaled_sales2","scaled_sales3",
            'scaled_promo','scaled_diff1','scaled_diff2','percentage_diff1','scaled_price',"scaled_rolling2"],
    
    "final": [1027, 1035,  144, 1051,  546, 1058,  549, 1065,  554,  686,  688,
       1206,"group_A","group_B",'scaled_dayofyear','scaled_dayofmonth','scaled_weekofyear',"scaled_sales1",'scaled_price',"xgb","extra"]
 
}

finalreg = RandomForestRegressor(n_estimators=100)

# %% [markdown]
# ### SCALING FUNCTIONS

# %%
min_max_scaler = preprocessing.MinMaxScaler()

def scale(feature, scaler = min_max_scaler):
    size = len(feature)
    return scaler.fit_transform(np.array([feature]).reshape(size, 1)).T[0]
def unscale(scaled, original, scaler = min_max_scaler):
    size2 = len(scaled)
    size1 = len(original)
    return scaler.fit(np.array([original]).reshape(size1, 1)).inverse_transform(np.array([scaled]).reshape(size2, 1)).T[0]

# %% [markdown]
# ### MAPE AND PLOT FUNCTIONS

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def plot_results(ytrue, prediction, label):
    df_ytrue = pd.DataFrame(ytrue)
    df_ytrue['predicted'] =  prediction 
    plt.plot(df_ytrue[label],label='data')
    plt.plot(df_ytrue['predicted'],label='predicted')
    plt.xticks(rotation=45)
    mape = mean_absolute_percentage_error(df_ytrue[label],df_ytrue['predicted'])

    plt.title("Forecasting on Test Set MAPE=%.3f"%mape)
    plt.legend();
    plt.show()
    return mape

def scaled_mape(prediction, y_test, rescale):
    results = pd.DataFrame(columns = ["sku","target","prediction"])

    for sku in y_test["sku"].unique():

        pred_sku = prediction[np.where(y_test["sku"] == sku)]
        originals = rescale.loc[rescale["sku"] == sku]["target"]
        pred = unscale(pred_sku,originals)

        results = pd.concat([results, pd.DataFrame({
            "date" : y_test[y_test["sku"] == sku]["date"],
            "sku" : y_test[y_test["sku"] == sku]["sku"],
            "scaled_target" : y_test[y_test["sku"] == sku]["scaled_target"],
            "target" : y_test[y_test["sku"] == sku]["target"],
            "scaled_prediction" : pred_sku,
            "prediction" : pred
        })])
    results = results.dropna().set_index("date")
    return mean_absolute_percentage_error(results["target"],results["prediction"])

    
    
    
def plot_scaled_results(prediction, y_test, rescale):
    results = pd.DataFrame(columns = ["sku","target","prediction"])

    for sku in y_test["sku"].unique():

        pred_sku = prediction[np.where(y_test["sku"] == sku)]
        originals = rescale.loc[rescale["sku"] == sku]["target"]
        pred = unscale(pred_sku,originals)

        results = pd.concat([results, pd.DataFrame({
            "date" : y_test[y_test["sku"] == sku]["date"],
            "sku" : y_test[y_test["sku"] == sku]["sku"],
            "scaled_target" : y_test[y_test["sku"] == sku]["scaled_target"],
            "target" : y_test[y_test["sku"] == sku]["target"],
            "scaled_prediction" : pred_sku,
            "prediction" : pred
        })])
    results = results.dropna().set_index("date")

    return plot_results(results["target"], results["prediction"], "target"), results

# %% [markdown]
# ### FUNCTION THAT COMPUTE THE CROSS PREDICTION OF THE TRAINING SET

# %%
def predict_training(model,X,y,label = "scaled_target",span = 24):
    
    #k = number of folds
    k = int(len(X)/span)
    
    prediction = pd.DataFrame(columns = ["date","sku","pred"])    
    
    for fold in range(0,k):
        if fold != k - 1:
            validation = X.iloc[fold*span:(fold+1)*span]
        else:
            validation = X.iloc[fold*span:]
        
        training = X[~X.index.isin(validation.index)]
        y_tr  = y[~y.index.isin(validation.index)]
        y_val  = y[y.index.isin(validation.index)]
        
        model.fit(training, y_tr[label])
        partial_pred = pd.DataFrame()
        partial_pred["date"] = y_val["date"]
        partial_pred["sku"] = y_val["sku"]
        partial_pred["pred"] = model.predict(validation)
        partial_pred.set_index(validation.index)
        prediction = prediction.append(partial_pred)
        
    return prediction

# %% [markdown]
# ### FUNCTION THAT COMPUTE THE PREDITION OF THE TEST SET STACKING ALL THE MODELS

# %%
def StackingPred(models,final_model, X_train, y_train, X_test,y_test,features_for_model,rescale = None, span = 24, label = "scaled_target"):
    final_prediction = []
    onehot_encoder = OneHotEncoder(sparse=False)
    
    y_traing = y_train
    X_traing = X_train
    sku_dummies = pd.get_dummies(y_traing["sku"]) > 0
    sku_dummies_df = pd.DataFrame(sku_dummies, index = X_traing.index)
    X_traing = pd.concat([sku_dummies_df,X_traing],axis = 1)
    
    for week in y_test.date.unique():
        print(week)
        
        test = X_test.loc[y_test.date == week]
        y_te = y_test.loc[y_test.date == week]
        
        #TRAIN SET PREDICTION WITH MODELS
        results_dict = {}
        print(X_traing.dropna().shape)
        for name, model in models.items():
            
            print("train with %s shape: %d x %d" %(name,X_traing.shape[0],X_traing.shape[1]))            
            results_dict.update({name : predict_training(model, X_traing, y_traing,label,span)})

        train_result = pd.DataFrame(index = X_traing.index)
        for name,r in results_dict.items():
            train_result["date"] = r["date"]
            train_result["sku"] = r["sku"]
            train_result[name] = r["pred"]
        onehot_encoded = pd.get_dummies(y_te["sku"]) > 0
        onehot = pd.DataFrame(onehot_encoded, index = test.index)
        test = pd.concat([onehot,test],axis = 1)

        #TEST SET PREDICTION WITH MODELS
        prediction_df = pd.DataFrame()
        for name, model in models.items():
            print("test with %s" %name)
          
            model = model.fit(X_traing, y_traing[label])

            prediction_df[name] = model.predict(test)
        prediction_df.index = test.index

        #DUMMY VARIABLES FOR FINAL TRAIN AND TEST
        final_train = pd.concat([X_traing,train_result[models.keys()]],axis = 1)
        final_test = pd.concat([test,prediction_df[models.keys()]],axis = 1)
       # print(final_test)
        #TRAIN ON TRAIN PREDICTIONS AND PREDICTION ON TEST PREDICTIONS
        print("final prediction")


        final_model.fit(final_train[features_for_model["final"]], y_traing[label])
        p =  final_model.predict(final_test[features_for_model["final"]])
        final_prediction = np.append(final_prediction,p)
        if rescale is not None:
            print("MAPE finale %.5f" % scaled_mape(p, y_te, rescale))
            print("MAPE xgb %.5f" % scaled_mape(np.array(prediction_df["xgb"]), y_te, rescale))
            print("MAPE extra %.5f" % scaled_mape(np.array(prediction_df["extra"]), y_te, rescale))
        X_traing = pd.concat([X_traing,test]).reset_index().drop(columns=["index"])
        y_traing = pd.concat([y_traing,y_te]).reset_index().drop(columns=["index"])
    return final_prediction, train_result, prediction_df

# %% [markdown]
# ### GET PROCESSED DATA FROM CSV

# %%
df = pd.read_csv('data/processed_train.csv',index_col = 0)
df_test = pd.read_csv('data/processed_test.csv',index_col = 0)

df = df.loc[df.scope == 1]
df_test = df_test.loc[df.scope == 1]
df.date = df.date.apply(lambda x:datetime.strptime(x, '%Y-%m-%d'))
df_test.date = df_test.date.apply(lambda x:datetime.strptime(x, '%Y-%m-%d'))

df = df.sort_values(by=["date",'sku'])
df_test = df_test.sort_values(by=["date",'sku'])

# %%
rescale_df = pd.concat([df,df_test])[["target","sku"]].dropna()

# %%
df = pd.concat([df,df_test])

# %% [markdown]
# ### FIRST FEATURE SELECTION

# %%
simple_df = df[['scaled_quarter','scaled_month','scaled_year','scaled_price_diff1',
            "group_A","group_B","BRAND2","BRAND4",
           'scaled_dayofyear','scaled_dayofmonth','scaled_weekofyear',"scaled_sales1","scaled_sales2","scaled_sales3",
            'scaled_promo','scaled_diff1','scaled_diff2','percentage_diff1','scaled_price',"scaled_rolling2",
                "date","sku","scaled_target","target"]]
simple_df = simple_df.dropna().set_index("date")
simple_train = simple_df[:SplitTestDate].reset_index()
simple_test = simple_df[SplitTestDate:].reset_index()

# %%
X_train = simple_train[['scaled_month',
            "group_A","group_B","BRAND2","BRAND4",
           'scaled_dayofyear','scaled_dayofmonth','scaled_weekofyear',"scaled_sales1","scaled_sales2","scaled_sales3",
            'scaled_promo','scaled_diff1','scaled_diff2','percentage_diff1','scaled_price',"scaled_rolling2"]]

# %%
y_train = simple_train[["date","sku","scaled_target","target"]]

# %%
X_test = simple_test[X_train.columns]

# %%
y_test = simple_test[y_train.columns]

# %%
X = pd.concat([X_train,X_test.loc[y_test.date == y_test.date.unique()[0]]])

# %%
X.reset_index().drop(columns=["index"])
# Out:
#       scaled_month  group_A  group_B  BRAND2  BRAND4  scaled_dayofyear  \
# 0         1.000000    False     True    True   False          1.000000
# 1         1.000000     True    False    True   False          1.000000
# 2         1.000000     True    False    True   False          1.000000
# 3         1.000000     True    False    True   False          1.000000
# 4         1.000000    False     True   False    True          1.000000
# ...            ...      ...      ...     ...     ...               ...
# 1567      0.454545     True    False    True   False          0.484765
# 1568      0.454545    False     True   False    True          0.484765
# 1569      0.454545     True    False   False    True          0.484765
# 1570      0.454545     True    False   False    True          0.484765
# 1571      0.454545     True    False   False    True          0.484765
#
#       scaled_dayofmonth  scaled_weekofyear  scaled_sales1  scaled_sales2  \
# 0              1.000000           1.000000       0.407090       0.486490
# 1              1.000000           1.000000       0.090556       0.109741
# 2              1.000000           1.000000       0.106018       0.102699
# 3              1.000000           1.000000       0.098738       0.121289
# 4              1.000000           1.000000       0.322606       0.418289
# ...                 ...                ...            ...            ...
# 1567           0.933333           0.490196       0.142010       0.192205
# 1568           0.933333           0.490196       0.048828       0.116144
# 1569           0.933333           0.490196       0.212171       0.254172
# 1570           0.933333           0.490196       0.221990       0.253979
# 1571           0.933333           0.490196       0.158397       0.208994
#
#       scaled_sales3  scaled_promo  scaled_diff1  scaled_diff2  \
# 0          0.359256      1.000000      0.079400     -0.047834
# 1          0.138842      0.119108      0.019184      0.048286
# 2          0.131821      0.203441     -0.003319      0.025803
# 3          0.154270      0.207252      0.022552      0.055532
# 4          0.333547      0.990468      0.095683      0.010941
# ...             ...           ...           ...           ...
# 1567       0.182352      0.077256      0.050195      0.040342
# 1568       0.104440      0.048294      0.067316      0.055612
# 1569       0.240136      0.226122      0.042001      0.027965
# 1570       0.255097      0.198803      0.031988      0.033107
# 1571       0.211487      0.102199      0.050597      0.053090
#
#       percentage_diff1  scaled_price  scaled_rolling2
# 0             0.165436      0.611354         0.446790
# 1             0.064815      0.633333         0.100149
# 2            -0.016304      0.777778         0.104359
# 3             0.068904      0.633333         0.110013
# 4             0.246065      0.579439         0.370447
# ...                ...           ...              ...
# 1567          0.166026      0.961538         0.167107
# 1568          0.484927      0.677570         0.082486
# 1569          0.116567      0.961538         0.233171
# 1570          0.069733      0.718750         0.237985
# 1571          0.126261      0.727273         0.183695
#
# [1572 rows x 17 columns]

# %% [markdown]
# ### COMPUTE THE PREDICTION

# %%
res = StackingPred(models,finalreg, X_train, y_train, X_test,y_test,features_for_model,rescale = rescale_df, span = 36, label = "scaled_target")
# Out:
# 2019-06-29T00:00:00.000000000
# (1560, 29)
# train with xgb shape: 1560 x 29
# train with extra shape: 1560 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 11.13917
# MAPE xgb 10.10316
# MAPE extra 10.06821
# 2019-07-06T00:00:00.000000000
# (1572, 29)
# train with xgb shape: 1572 x 29
# train with extra shape: 1572 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 9.03912
# MAPE xgb 9.65321
# MAPE extra 11.11580
# 2019-07-13T00:00:00.000000000
# (1584, 29)
# train with xgb shape: 1584 x 29
# train with extra shape: 1584 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 18.94329
# MAPE xgb 20.42367
# MAPE extra 19.01862
# 2019-07-20T00:00:00.000000000
# (1596, 29)
# train with xgb shape: 1596 x 29
# train with extra shape: 1596 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 22.93890
# MAPE xgb 23.21854
# MAPE extra 21.57253
# 2019-07-27T00:00:00.000000000
# (1608, 29)
# train with xgb shape: 1608 x 29
# train with extra shape: 1608 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 8.19176
# MAPE xgb 9.21671
# MAPE extra 9.04517
# 2019-08-03T00:00:00.000000000
# (1620, 29)
# train with xgb shape: 1620 x 29
# train with extra shape: 1620 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 10.85471
# MAPE xgb 15.63703
# MAPE extra 11.83239
# 2019-08-10T00:00:00.000000000
# (1632, 29)
# train with xgb shape: 1632 x 29
# train with extra shape: 1632 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 16.46988
# MAPE xgb 16.72274
# MAPE extra 14.63370
# 2019-08-17T00:00:00.000000000
# (1644, 29)
# train with xgb shape: 1644 x 29
# train with extra shape: 1644 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 15.04070
# MAPE xgb 11.63347
# MAPE extra 15.81002
# 2019-08-24T00:00:00.000000000
# (1656, 29)
# train with xgb shape: 1656 x 29
# train with extra shape: 1656 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 4.47366
# MAPE xgb 9.31078
# MAPE extra 8.78873
# 2019-08-31T00:00:00.000000000
# (1668, 29)
# train with xgb shape: 1668 x 29
# train with extra shape: 1668 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 6.24508
# MAPE xgb 4.97666
# MAPE extra 6.80640
# 2019-09-07T00:00:00.000000000
# (1680, 29)
# train with xgb shape: 1680 x 29
# train with extra shape: 1680 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 6.10542
# MAPE xgb 5.74502
# MAPE extra 4.06416
# 2019-09-14T00:00:00.000000000
# (1692, 29)
# train with xgb shape: 1692 x 29
# train with extra shape: 1692 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 6.72339
# MAPE xgb 9.04060
# MAPE extra 8.98796
# 2019-09-21T00:00:00.000000000
# (1704, 29)
# train with xgb shape: 1704 x 29
# train with extra shape: 1704 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 6.13807
# MAPE xgb 3.55888
# MAPE extra 4.47005
# 2019-09-28T00:00:00.000000000
# (1716, 29)
# train with xgb shape: 1716 x 29
# train with extra shape: 1716 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 4.44400
# MAPE xgb 3.39858
# MAPE extra 3.40222
# 2019-10-05T00:00:00.000000000
# (1728, 29)
# train with xgb shape: 1728 x 29
# train with extra shape: 1728 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 23.05644
# MAPE xgb 23.68892
# MAPE extra 20.61761
# 2019-10-12T00:00:00.000000000
# (1740, 29)
# train with xgb shape: 1740 x 29
# train with extra shape: 1740 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 6.94862
# MAPE xgb 6.61126
# MAPE extra 6.70459
# 2019-10-19T00:00:00.000000000
# (1752, 29)
# train with xgb shape: 1752 x 29
# train with extra shape: 1752 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 5.46690
# MAPE xgb 8.31208
# MAPE extra 5.11479
# 2019-10-26T00:00:00.000000000
# (1764, 29)
# train with xgb shape: 1764 x 29
# train with extra shape: 1764 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 8.08711
# MAPE xgb 7.82821
# MAPE extra 8.08534
# 2019-11-02T00:00:00.000000000
# (1776, 29)
# train with xgb shape: 1776 x 29
# train with extra shape: 1776 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 11.40032
# MAPE xgb 6.41015
# MAPE extra 8.46283
# 2019-11-09T00:00:00.000000000
# (1788, 29)
# train with xgb shape: 1788 x 29
# train with extra shape: 1788 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 5.80516
# MAPE xgb 4.79074
# MAPE extra 6.07312
# 2019-11-16T00:00:00.000000000
# (1800, 29)
# train with xgb shape: 1800 x 29
# train with extra shape: 1800 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 8.89112
# MAPE xgb 13.66010
# MAPE extra 10.99821
# 2019-11-23T00:00:00.000000000
# (1812, 29)
# train with xgb shape: 1812 x 29
# train with extra shape: 1812 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 6.47578
# MAPE xgb 10.52645
# MAPE extra 8.88456
# 2019-11-30T00:00:00.000000000
# (1824, 29)
# train with xgb shape: 1824 x 29
# train with extra shape: 1824 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 5.91267
# MAPE xgb 7.57621
# MAPE extra 3.36507
# 2019-12-07T00:00:00.000000000
# (1836, 29)
# train with xgb shape: 1836 x 29
# train with extra shape: 1836 x 29
# test with xgb
# test with extra
# final prediction
# MAPE finale 5.09299
# MAPE xgb 8.01070
# MAPE extra 7.16273

# %%
res
# Out:
# (array([0.06562017, 0.11868258, 0.11600666, 0.18958786, 0.06071405,
#         0.12668217, 0.15228235, 0.1223134 , 0.07098734, 0.17018647,
#         0.18462905, 0.14442548, 0.07054522, 0.11262545, 0.11821676,
#         0.14494009, 0.10410832, 0.1569828 , 0.11477302, 0.09772565,
#         0.08385167, 0.15348072, 0.13731596, 0.13646497, 0.11875601,
#         0.18218147, 0.28540444, 0.20783633, 0.19540576, 0.29737648,
#         0.27545365, 0.15763343, 0.15710664, 0.33693595, 0.28364108,
#         0.31928162, 0.08408502, 0.30190628, 0.29713052, 0.36101855,
#         0.22265804, 0.30163379, 0.27414666, 0.64656445, 0.10331263,
#         0.5881826 , 0.35309245, 0.53212127, 0.09731924, 0.41982266,
#         0.43568877, 0.40498403, 0.11035108, 0.44344803, 0.44048855,
#         0.43761782, 0.17372464, 0.39101635, 0.38711982, 0.46955375,
#         0.38226597, 0.22093924, 0.27484753, 0.19666732, 0.41552865,
#         0.23753915, 0.21784527, 0.24587012, 0.4282741 , 0.21559651,
#         0.15799092, 0.29027224, 0.49571888, 0.14936043, 0.12187292,
#         0.12686003, 0.5839565 , 0.12432088, 0.13183375, 0.13056142,
#         0.60250883, 0.12637398, 0.14796397, 0.14949178, 0.52891551,
#         0.07070233, 0.11213196, 0.13203423, 0.81433079, 0.10972526,
#         0.106824  , 0.10127172, 0.69579227, 0.1416766 , 0.14222265,
#         0.1207661 , 0.26539622, 0.09336171, 0.09504031, 0.14652647,
#         0.26732741, 0.11133523, 0.08362299, 0.09378077, 0.36120021,
#         0.13675967, 0.14729027, 0.10066639, 0.13372525, 0.08636447,
#         0.1036138 , 0.14264892, 0.13133912, 0.10572494, 0.08335379,
#         0.09293281, 0.13595102, 0.14160706, 0.13737447, 0.11022855,
#         0.09946639, 0.08259373, 0.14452205, 0.21923019, 0.08988424,
#         0.17601233, 0.10557444, 0.12607622, 0.14905105, 0.18818276,
#         0.20316406, 0.17126428, 0.09327218, 0.32423369, 0.32149779,
#         0.31823001, 0.11570773, 0.31687371, 0.27276109, 0.31679283,
#         0.15158543, 0.31568267, 0.16524724, 0.35624371, 0.09078096,
#         0.45352446, 0.44633381, 0.47417721, 0.09201576, 0.44053965,
#         0.43536277, 0.44674075, 0.15070835, 0.45356354, 0.46715018,
#         0.52364697, 0.09075859, 0.49227125, 0.42524259, 0.52964881,
#         0.10611959, 0.51291281, 0.36462663, 0.41100432, 0.15636621,
#         0.49501845, 0.51102649, 0.49655487, 0.64167265, 0.25765382,
#         0.26470839, 0.27424065, 0.36486492, 0.64981283, 0.22959469,
#         0.20009802, 0.45173043, 0.25960925, 0.25764975, 0.25002352,
#         0.47919625, 0.08784879, 0.10412405, 0.11706124, 0.51663792,
#         0.10474667, 0.05704647, 0.06612362, 0.56480448, 0.10606952,
#         0.11623537, 0.10938037, 0.48662225, 0.07548794, 0.0876726 ,
#         0.15551979, 0.4991429 , 0.10419893, 0.07325717, 0.08504551,
#         0.61061613, 0.11306869, 0.13664062, 0.09098698, 0.25332116,
#         0.46439152, 0.4581387 , 0.48197327, 0.27062564, 0.54109642,
#         0.46181378, 0.44615886, 0.31309249, 0.56427718, 0.53282822,
#         0.48871024, 0.11231457, 0.73595653, 0.80752678, 0.86785461,
#         0.12392098, 0.86863313, 0.5728241 , 0.7472546 , 0.14466677,
#         0.7980813 , 0.80276124, 0.78094762, 0.08481293, 0.6548242 ,
#         0.76074111, 0.74279068, 0.11203382, 0.81355989, 0.48794209,
#         0.75332163, 0.15475193, 0.7659662 , 0.7406757 , 0.73602881,
#         0.37475648, 0.34601381, 0.34448767, 0.37118266, 0.3850167 ,
#         0.38933276, 0.29306429, 0.34191564, 0.46889395, 0.3501865 ,
#         0.34638978, 0.36072128, 0.46202504, 0.08282975, 0.08536221,
#         0.13543286, 0.49245356, 0.09826489, 0.08305576, 0.0885733 ,
#         0.64100961, 0.09850664, 0.10115341, 0.09864773, 0.48506438,
#         0.06407566, 0.08177044, 0.16959993, 0.56466302, 0.10123234,
#         0.06520473, 0.0800706 , 0.61432319, 0.10203334, 0.07860978,
#         0.06931   , 0.25122274, 0.06212286, 0.08746807, 0.17125892,
#         0.2517288 , 0.13137789, 0.09443274, 0.09524094, 0.29353579,
#         0.15844312, 0.10142944, 0.09603519]),
#             date   sku       xgb     extra
#  0    2016-12-31   144  0.087539  0.135590
#  1    2016-12-31   546  0.041151  0.137399
#  2    2016-12-31   549  0.052546  0.099776
#  3    2016-12-31   554  0.081519  0.151485
#  4    2016-12-31   686  0.106810  0.143632
#  ...         ...   ...       ...       ...
#  1831 2019-11-30  1035  0.094844  0.084921
#  1832 2019-11-30  1051  0.645868  0.630940
#  1833 2019-11-30  1058  0.131033  0.106326
#  1834 2019-11-30  1065  0.099870  0.091352
#  1835 2019-11-30  1206  0.092220  0.083984
#
#  [1836 rows x 4 columns],
#            xgb     extra
#  276  0.262489  0.249691
#  277  0.108668  0.098876
#  278  0.124444  0.115441
#  279  0.178588  0.177966
#  280  0.233377  0.250585
#  281  0.139454  0.141948
#  282  0.106473  0.104525
#  283  0.118013  0.115656
#  284  0.318602  0.308508
#  285  0.143868  0.152082
#  286  0.121626  0.118418
#  287  0.118965  0.106970)

# %% [markdown]
# ### SHOW THE RESULTS

# %%
mape,results = plot_scaled_results(res[0], y_test, rescale_df)

# %%
results
# Out:
#              sku    target     prediction  scaled_target  scaled_prediction
# date
# 2019-06-29   144   16228.0   16446.379298       0.063781           0.065620
# 2019-07-06   144   18114.0   17031.302683       0.079662           0.070545
# 2019-07-13   144   18748.0   22757.057896       0.085000           0.118756
# 2019-07-20   144   17833.0   18639.357231       0.077295           0.084085
# 2019-07-27   144   17105.0   20211.119562       0.071166           0.097319
# ...          ...       ...            ...            ...                ...
# 2019-11-09  1206  111353.0  114219.683473       0.711474           0.736029
# 2019-11-16  1206   63359.0   70404.405635       0.300373           0.360721
# 2019-11-23  1206   35238.0   39808.629001       0.059497           0.098648
# 2019-11-30  1206   34242.0   36383.595960       0.050966           0.069310
# 2019-12-07  1206   37889.0   39503.627932       0.082205           0.096035
#
# [288 rows x 5 columns]
